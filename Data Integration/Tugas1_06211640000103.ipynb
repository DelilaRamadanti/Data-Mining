# %%
import pandas as pd
data1=pd.read_csv('datatugas1.csv',sep=';')
data2=pd.read_csv('datatugas2.csv',sep=';')
data_gabungan= pd.merge(data1,data2, on='KABUPATEN')
data_gabungan
# Out:
#                 KABUPATEN    JUMLAH SUB JUMLAH Kerapu  Mujair  Tawes  Kakap  \
# 0          JUMLAH 0 TOTAL  191610,2   124807,4  475,5  8544,2      0  402,3
# 1         KABUPATEN TUBAN      5038       1238   23,6   147,3      0      0
# 2      KABUPATEN LAMONGAN    3972,6     1379,2  306,6   131,2      0      0
# 3        KABUPATEN GRESIK     48185    42530,4   66,7  1734,9      0      0
# 4           KOTA SURABAYA    6530,3       5120      0       0      0      0
# 5     KABUPATEN BANGKALAN    2860,2     1695,8      0   307,2      0  264,8
# 6       KABUPATEN SAMPANG    5249,8     3628,5      0   633,5      0      0
# 7     KABUPATEN PAMEKASAN     520,9       37,8      0       0      0      0
# 8       KABUPATEN SUMENEP    1116,1      715,7      0   149,1      0      0
# 9      KABUPATEN SIDOARJO   77266,8    57897,3      0  3748,2      0      0
# 10     KABUPATEN PASURUAN   11346,4     6937,5      0  1506,9      0      0
# ...
